# %%
# What is Matplotlib ? 
#ans- Matplotlib is a cross-platform, data visualization and graphical plotting library (histograms, scatter plots, bar charts, etc) for Python and its numerical extension NumPy. As such, it offers a viable open source alternative to MATLAB. Developers can also use matplotlib’s APIs (Application Programming Interfaces) to embed plots in GUI applications.

# Why is it used - Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.
# 5 plot that can be plotted using the pyplot module are -
#1.> Bar Graph using matplotlib. ...
#2.> Pie Chart using matplotlib. ...
#3.> 3. Box Plot using matplotlib. ...
#4.> Histogram using matplotlib. ...
#5.> Line Plot and Subplots using matplotlib. ...
#6.> Scatter Plot using matplotlib.

# %%
# What is a scatter plot ?
#ans- A scatter plot is a visual representation of how two variables relate to each other. You can use scatter plots to explore the relationship between two variables, for example by looking for any correlation between them.
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(3)
x=3+np.random.normal(0,2,50)
y=3+np.random.normal(0,2,len(x))
plt.plot(x,y)
plt.title("Scatter Plot")
plt.xlabel("x axis")
plt.ylabel("y axis")
# Out:
# Text(0, 0.5, 'y axis')

# %%
# Ques3- why is subplot()function is used ?
# ans - subplot() function in Python. subplot() function adds subplot to a current figure at the specified grid position. It is similar to the subplots() function however unlike subplots() it adds one subplot at a time. So to create multiple plots you will need several lines of code with the subplot() function.
import numpy as np 
x=np.array([0,1,2,3,4,5]) and y=np.array([0,100,200,300,400,500])
x=np.array([0,1,2,3,4,5]) and y=np.array([50,20,40,20,60,70])
x=np.array([0,1,2,3,4,5]) and y=np.array([10,20,30,40,50,60])
x=np.array([0,1,2,3,4,5]) and y=np.array([200,350,250,550,450,150])
fig = plt.figure()
ax = fig.add_subplot(projection ='2d')
plt.scatter(x,y)
plt.show()
# Out:
#   Cell In[7], line 4
#     x=np.array([0,1,2,3,4,5]) and y=np.array([0,100,200,300,400,500])
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
#Ques 4 - What is bar plot ? and why is it used ?
# ans -  Bar plots are a type of data visualization used to represent data in the form of rectangular bars. The height of each bar represents the value of a data point, and the width of each bar represents the category of the data. The Matplotlib library in Python is widely used to create bar plots.
import numpy as np 
company=np.array(["Apple","Microsoft","Google","AMD"])
profit=np.array([3000,8000,1000,10000])
plt.bar(company,profit)
plt.xlabel("Company name")
plt.ylabel("profit")
plt.title("bar graph ")
# Out:
# Text(0.5, 1.0, 'bar graph ')

# %%
import numpy as np 
company=np.array(["Apple","Microsoft","Google","AMD"])
profit=np.array([3000,8000,1000,10000])
plt.barh(company,profit)
plt.xlabel("Company name")
plt.ylabel("profit")
plt.title("Horizontal bar graph ")
# Out:
# Text(0.5, 1.0, 'Horizontal bar graph ')

# %%
#Ques5 - What is a Box plot ? Why is it used ? 
#ans- A Box Plot is also known as Whisker plot is created to display the summary of the set of data values having properties like minimum, first quartile, median, third quartile and maximum.
import pandas as pd
box1=np.random.normal(100,10,200)
box2=np.random.normal(90,20,200)
plt.boxplot(box1,box2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 6
#       4 box1=np.random.normal(100,10,200)
#       5 box2=np.random.normal(90,20,200)
# ----> 6 plt.boxplot(box1,box2)
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/pyplot.py:2411, in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths, data)
#    2401 @_copy_docstring_and_deprecators(Axes.boxplot)
#    2402 def boxplot(
#    2403         x, notch=None, sym=None, vert=None, whis=None,
#    (...)
#    2409         whiskerprops=None, manage_ticks=True, autorange=False,
#    2410         zorder=None, capwidths=None, *, data=None):
# -> 2411     return gca().boxplot(
# ...
